# %%
import os
from shutil import copytree
OK_DIRS_100 = [ "blw-eng", "pao-eng", "ita-eng", "etr-eng", "esu-eng", "tee-eng", "agm-eng", "fuv-eng", "mqy-eng", "cnt-eng", "tat-eng", "ses-eng", "ote-eng", "xsi-eng", "nmf-eng", "miz-eng", "cpa-eng", "ctd-eng", "mvn-eng", "hye-eng", "etu-eng", "kor-eng", "tvk-eng", "rim-eng", "plt-eng", "por-eng", "rop-eng", "fra-eng", "pib-eng", "crx-eng", "abt-eng", "bqc-eng", "inb-eng", "mks-eng", "kbp-eng", "cap-eng", "ktu-eng", "ixl-eng", "kbq-eng", "nhx-eng", "rro-eng", "adj-eng", "ron-eng", "zab-eng", "wed-eng", "bpr-eng", "mya-eng", "mjc-eng", "agt-eng", "cta-eng", "tav-eng", "miq-eng", "kde-eng", "car-eng", "kmo-eng", "ons-eng", "tui-eng", "cax-eng", "tob-eng", "jiv-eng", "apn-eng", "cco-eng", "cbc-eng", "fin-eng", "sps-eng", "caq-eng", "tgl-eng", "tnk-eng", "nuy-eng", "spp-eng", "bhg-eng", "mua-eng", "nak-eng", "bum-eng", "otq-eng", "ksf-eng", "amn-eng", "mva-eng", "apw-eng", "trp-eng", "pwg-eng", "ndi-eng", "kac-eng", "cbs-eng", "aca-eng", "nko-eng", "adi-eng", "bdh-eng", "sus-eng", "geb-eng", "kup-eng", "tos-eng", "ncj-eng", "trc-eng", "mie-eng", "ban-eng", "kto-eng", "guo-eng", "sua-eng", "urd-eng" ]

# %%
path_src = "/home/ubuntu/project11737-reprise/data/bible-com/"
path_out = "/home/ubuntu/project11737-reprise/data/toy100/bible-com/"
for path in OK_DIRS_100:
    path = path.replace("-","_")
    src = path_src+path
    dest = path_out+path
    destination = copytree(src, dest)  
    print(destination)
# Out:
# /home/ubuntu/project11737-reprise/data/toy100/bible-com/blw_eng
# /home/ubuntu/project11737-reprise/data/toy100/bible-com/pao_eng
# /home/ubuntu/project11737-reprise/data/toy100/bible-com/ita_eng
# /home/ubuntu/project11737-reprise/data/toy100/bible-com/etr_eng
# /home/ubuntu/project11737-reprise/data/toy100/bible-com/esu_eng
# /home/ubuntu/project11737-reprise/data/toy100/bible-com/tee_eng
# /home/ubuntu/project11737-reprise/data/toy100/bible-com/agm_eng
# /home/ubuntu/project11737-reprise/data/toy100/bible-com/fuv_eng
# /home/ubuntu/project11737-reprise/data/toy100/bible-com/mqy_eng
# /home/ubuntu/project11737-reprise/data/toy100/bible-com/cnt_eng
# /home/ubuntu/project11737-reprise/data/toy100/bible-com/tat_eng
# /home/ubuntu/project11737-reprise/data/toy100/bible-com/ses_eng
# /home/ubuntu/project11737-reprise/data/toy100/bible-com/ote_eng
# /home/ubuntu/project11737-reprise/data/toy100/bible-com/xsi_eng
# /home/ubuntu/project11737-reprise/data/toy100/bible-com/nmf_eng
# ...
